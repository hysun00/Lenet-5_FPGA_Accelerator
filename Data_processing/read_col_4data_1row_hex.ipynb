# %% [markdown]
# ## Python code for reading the data from csv per column and change the data(int) into hex value arrangement into 4 data a row

# %%
import pandas as pd
import csv
import numpy as np
col_list = ["283","776","161","515","640","745","486","210","70","325","335","881","339","977","880","322","348","491","945","828","906","461","203","277","89","703","811","865","66","11","113","911","481","143","847","78","955","749","68","295","707","207","672","463","604","128","777","63","841","888","160","243","509","870","642","416","601","249","756","246","110","122","87","111","673","19","492","804","632","388","588","441","965","236","886","985","899","564","982","363","209","226","293","177","800","343","922","290","575","144","825","129","572","300","334","792","901","950","783","730","558","921","324","878","434","187","58","265","37","696","948","323","74","28","429","79","902","309","645","927","275","665","392","56","41","27","538","893","465","770","727","754","662","998","898","6","456","534","533","305","476","417","897","291","701","371","559","641","900","646","737","234","204","469","580","460","648","218","278","889","381","489","683","365","233","54","169","303","961","314","631","493","380","576","176","890","136","993","885","535","168","869","247","280","887","590","459","830","668","621","528","781","517","664","346","768","135","157","789","77","613","685","938","297","723","239","276","744","589","49","214","488","529","347","970","390","705","896","884","691","185","611","844","725","26","393","819","864","655","374","35","292","15","599","709","361","755","373","848","835","34","999","699","513","822"]
df = pd.read_csv("number_mnist.csv", usecols=col_list)
count = 0
list = []
f=open('./number_245_test.hex','a')
for x in range(245):
    for i in df[col_list[x]]:
        count+=1
        if count > 2:
            list.append(int(i))
    l_hex = ['{:02x}'.format(i) for i in list]
    arr_2d = np.reshape(l_hex, (256,4))  
    print(arr_2d)
    np.savetxt(f, arr_2d, delimiter ="",fmt ='% s')
    count = 0
    list *= 0
    l_hex *= 0

    
    
f.close()

# %%
list1 = [529,937,21,226,780,290,599,440,358,627,294,946,995,782,838,840,420,815,648,608,477,118,383,539,798,237,124,817,104,528,520,244,645,999,544,177,632,488,199,788,642,506,585,754,971,604,51,791,4,931,610,251,127,67,91,208,467,963,756,486,418,228,90,968,140,33,898,747,631,454,530,881,775,606,922,36,870,656,887,436,536,435,639,404,211,340,702,433,636,5,741,568,888,368,173,790,785,763,549,701,421,356]
listt = []

for i in list1:
    listt.append(str(i))

# %%
import pandas as pd
import csv
import numpy as np
df = pd.read_csv("letter_emnist.csv", usecols=listt)
count = 0
list = []
f=open('./letter_102_test.hex','a')
for x in range(102):
    for i in df[listt[x]]:
        count+=1
        if count > 2:
            list.append(int(i))
    l_hex = ['{:02x}'.format(i) for i in list]
    arr_2d = np.reshape(l_hex, (256,4))  
    print(arr_2d)
    np.savetxt(f, arr_2d, delimiter ="",fmt ='% s')
    count = 0
    list *= 0
    l_hex *= 0

    
    
f.close()
# Out:
# [['00' '00' '00' '00']
#  ['00' '00' '00' '00']
#  ['00' '00' '00' '00']
#  ...
#  ['00' '00' '00' '00']
#  ['00' '00' '00' '00']
#  ['00' '00' '00' '00']]
# [['00' '00' '00' '00']
#  ['00' '00' '00' '00']
#  ['00' '00' '00' '00']
#  ...
#  ['00' '00' '00' '00']
#  ['00' '00' '00' '00']
#  ['00' '00' '00' '00']]
# [['00' '00' '00' '00']
#  ['00' '00' '00' '00']
#  ['00' '00' '00' '00']
#  ...
#  ['00' '00' '00' '00']
#  ['00' '00' '00' '00']
#  ['00' '00' '00' '00']]
# [['00' '00' '00' '00']
#  ['00' '00' '00' '00']
#  ['00' '00' '00' '00']
#  ...
#  ['00' '00' '00' '00']
#  ['00' '00' '00' '00']
#  ['00' '00' '00' '00']]
# [['00' '00' '00' '00']
#  ['00' '00' '00' '00']
#  ['00' '00' '00' '00']
#  ...
#  ['00' '00' '00' '00']
#  ['00' '00' '00' '00']
#  ['00' '00' '00' '00']]
# [['00' '00' '00' '00']
#  ['00' '00' '00' '00']
#  ['00' '00' '00' '00']
#  ...
#  ['00' '00' '00' '00']
#  ['00' '00' '00' '00']
#  ['00' '00' '00' '00']]
# [['00' '00' '00' '00']
#  ['00' '00' '00' '00']
# ...
